# %% [markdown]
# <a href="https://colab.research.google.com/github/jaswu51/ComputerVision/blob/main/explorePixels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # check how a normal image looks like in R, G, B channels

# %%
import torch
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
image = Image.open('/content/1.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7FCF385F3410>

# %%
transform = transforms.Compose([
    transforms.Resize(100),
    transforms.ToTensor(),
    # transforms.Normalize(0.5,0.5,0.5)
])

# %%
a=transform(image)

# %% [markdown]
# ### 3 color channels in the tensor format

# %%
print(a)
# Out:
# tensor([[[0.5529, 0.5333, 0.4941,  ..., 0.0784, 0.1529, 0.1686],
#          [0.5412, 0.5098, 0.4863,  ..., 0.0902, 0.1686, 0.2902],
#          [0.5059, 0.4784, 0.4745,  ..., 0.1098, 0.3176, 0.4824],
#          ...,
#          [0.4235, 0.5176, 0.5490,  ..., 0.7255, 0.6902, 0.5961],
#          [0.4196, 0.5216, 0.5451,  ..., 0.6824, 0.5843, 0.5412],
#          [0.4039, 0.5137, 0.5569,  ..., 0.5765, 0.5176, 0.5373]],
#
#         [[0.8980, 0.8902, 0.8431,  ..., 0.6353, 0.6275, 0.6353],
#          [0.8863, 0.8667, 0.8353,  ..., 0.6000, 0.6235, 0.5725],
#          [0.8549, 0.8314, 0.8196,  ..., 0.5882, 0.5490, 0.3961],
#          ...,
#          [0.7882, 0.8941, 0.9294,  ..., 0.3961, 0.3647, 0.3216],
#          [0.7882, 0.9137, 0.9333,  ..., 0.3804, 0.3059, 0.3216],
#          [0.7804, 0.9098, 0.9216,  ..., 0.3294, 0.2902, 0.3098]],
#
#         [[0.6314, 0.6157, 0.5608,  ..., 0.4667, 0.4706, 0.4549],
#          [0.6196, 0.6039, 0.5804,  ..., 0.4745, 0.4784, 0.4157],
# ...

# %%
a.size()
# Out:
# torch.Size([3, 100, 100])

# %%
F.to_pil_image(a)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FCF386A17D0>

# %% [markdown]
# # visualize the 3-channel tensor created by hand

# %% [markdown]
# conclusion:
#
# since only the Red channels contain the value, the final line is in red color.
#
# since our pixel value starts from -5, usually it is from 0 to 255, the negative values are looped back to the max pixel colors.

# %%
imgzeros = np.ones((260)) 
list=[i for i in range(-5,255)]
image = torch.Tensor([[imgzeros],[list],[imgzeros]]) #B,R,Y(yellow) 3 channels
transform=transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor()
 ]
)
image=transform(image)
F.to_pil_image(image)
# Out:
# <PIL.Image.Image image mode=RGB size=260x1 at 0x7FCF38602DD0>
